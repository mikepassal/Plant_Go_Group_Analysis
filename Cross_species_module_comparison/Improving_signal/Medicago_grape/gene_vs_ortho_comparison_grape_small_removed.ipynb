# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
arabi_genes = pd.read_csv('/data/passala/Module_paper_data/Medicago_grape_Redo_salt_pinot/medi_genes_de_results.csv', index_col= 0)
arabi_ortho = pd.read_csv('/data/passala/Module_paper_data/Medicago_grape_Redo_salt_pinot/medi_ortho_de_results_1_families_removed.csv', index_col= 0)
tomato_genes = pd.read_csv('/data/passala/Module_paper_data/Medicago_grape_Redo_salt_pinot/grape_genes_de_results.csv', index_col= 0)
tomato_ortho = pd.read_csv('/data/passala/Module_paper_data/Medicago_grape_Redo_salt_pinot/grape_ortho_de_results_1_families_removed.csv', index_col= 0)

# %%
log_fc_change_evaluation_value = 1
log_fc_change_evaluation_value_negative = -1*log_fc_change_evaluation_value

# %%
tomato_ortho
# Out:
#                  baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 10525at3193    122.643419       -0.165825  0.149290  -1.110753  2.666748e-01
# 10772at3193   2014.002469        0.063741  0.047467   1.342863  1.793164e-01
# 10950at3193   1946.606938       -0.015704  0.045522  -0.344970  7.301173e-01
# 109808at3193    36.495350        1.900279  0.310260   6.124788  9.080423e-10
# 109841at3193    91.120547       -0.169793  0.174726  -0.971766  3.311669e-01
# ...                   ...             ...       ...        ...           ...
# 9592at3193    1233.341671        0.131642  0.053807   2.446548  1.442317e-02
# 9601at3193    1081.122250        0.003692  0.059667   0.061875  9.506625e-01
# 9609at3193     607.655110       -1.082456  0.075459 -14.344919  1.146348e-46
# 9789at3193     957.908878       -0.112392  0.062001  -1.812739  6.987202e-02
# 9942at3193    1944.955196        0.118500  0.049328   2.402273  1.629353e-02
#
#                       padj
# 10525at3193   3.977019e-01
# 10772at3193   2.923092e-01
# 10950at3193   8.082822e-01
# 109808at3193  9.911468e-09
# 109841at3193  4.672132e-01
# ...                    ...
# 9592at3193    3.705554e-02
# 9601at3193    9.675091e-01
# 9609at3193    1.126136e-44
# 9789at3193    1.381527e-01
# 9942at3193    4.112491e-02
#
# [3733 rows x 6 columns]

# %%
trimmed_tomato_ortho = tomato_ortho.loc[tomato_ortho.index.isin(arabi_ortho.index)]
trimmed_arabi_ortho = arabi_ortho.loc[arabi_ortho.index.isin(trimmed_tomato_ortho.index)]

# %%
sns.scatterplot(x =trimmed_tomato_ortho['log2FoldChange'], y = trimmed_arabi_ortho['log2FoldChange'])
plt.axvline(0, color="grey", linestyle="--")
plt.axhline(0, color="grey", linestyle="--")

# %%
sns.scatterplot(x =trimmed_tomato_ortho['log2FoldChange'], y = trimmed_arabi_ortho['log2FoldChange'])
plt.axvline(2, color="grey", linestyle="--")
plt.axhline(2, color="grey", linestyle="--")
plt.axvline(-2, color="grey", linestyle="--")
plt.axhline(-2, color="grey", linestyle="--")

# %%
merged_result = pd.DataFrame(data = zip(trimmed_tomato_ortho['log2FoldChange'], trimmed_arabi_ortho['log2FoldChange']), columns = ['Grape','Medicago'])

all_over_1 = merged_result.loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']>log_fc_change_evaluation_value)]
all_under_1 = merged_result.loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]
discord_bottom = merged_result.loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]
discord_top = merged_result.loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']>log_fc_change_evaluation_value)]

# %%
discord_ratio = (len(all_over_1)+len(all_under_1))/(len(discord_bottom)+len(discord_top))
discord_ratio
# Out:
# 1.6363636363636365

# %%
merged_result['Classification'] = 'Non-substantial'
merged_result['Classification'].loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']>log_fc_change_evaluation_value)] = 'Substantial'
merged_result['Classification'].loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
merged_result['Classification'].loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
merged_result['Classification'].loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']>log_fc_change_evaluation_value)]= 'Substantial'
# Out:
# /tmp/ipykernel_512254/436749670.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result['Classification'].loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']>log_fc_change_evaluation_value)] = 'Substantial'
# /tmp/ipykernel_512254/436749670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result['Classification'].loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']>log_fc_change_evaluation_value)] = 'Substantial'
# /tmp/ipykernel_512254/436749670.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result['Classification'].loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/436749670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result['Classification'].loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/436749670.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result['Classification'].loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/436749670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result['Classification'].loc[(merged_result['Grape']>log_fc_change_evaluation_value) & (merged_result['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/436749670.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result['Classification'].loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']>log_fc_change_evaluation_value)]= 'Substantial'
# /tmp/ipykernel_512254/436749670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result['Classification'].loc[(merged_result['Grape']<log_fc_change_evaluation_value_negative) & (merged_result['Medicago']>log_fc_change_evaluation_value)]= 'Substantial'

# %%
fig, ax = plt.subplots(figsize = (12,8))
fig.patch.set_facecolor('white')
sns.scatterplot(data = merged_result.loc[merged_result['Classification'] == "Substantial"] , x = 'Grape', y = 'Medicago')
plt.axvline(0, color="k", linestyle="--")
plt.axhline(0, color="k", linestyle="--")
plt.axvline(1, color="grey", linestyle="--")
plt.axhline(1, color="grey", linestyle="--")
plt.axvline(-1, color="grey", linestyle="--")
plt.axhline(-1, color="grey", linestyle="--")
plt.xlabel("Orthogroup-wise log2-fold change in Grape", fontsize = 20)
plt.ylabel("Orthogroup-wise log2-fold chagne in Medicago", fontsize = 20)
plt.title('Orthogroupwise Grape vs Medicago (Note Log2FC cutoff set to 1)\n 1.63 Concordant Groups per Discordant Group', fontsize = 23)
plt.xticks(fontsize = 18,)
plt.yticks(fontsize = 18)
# Out:
# (array([-5. , -2.5,  0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. ]),
#  [Text(0, -5.0, '−5.0'),
#   Text(0, -2.5, '−2.5'),
#   Text(0, 0.0, '0.0'),
#   Text(0, 2.5, '2.5'),
#   Text(0, 5.0, '5.0'),
#   Text(0, 7.5, '7.5'),
#   Text(0, 10.0, '10.0'),
#   Text(0, 12.5, '12.5'),
#   Text(0, 15.0, '15.0')])

# %%
stats.spearmanr(a=trimmed_tomato_ortho['log2FoldChange'], b = trimmed_arabi_ortho['log2FoldChange'] )
# Out:
# SignificanceResult(statistic=0.15404291063710454, pvalue=9.68715540463325e-16)

# %%
arabidopsis_tomato_nm = pd.read_csv('/data/passala/OrthoDB_data/V_11_NM_with_NCBI/grape_to_medicago_ortholog_NM.csv')

# %%
arabidopsis_tomato_nm
# Out:
#       grape OrthoGene medicago OrthoGene   Orthogroup  grape Symbol  \
# 0      29760_0:005643      3880_0:00298d  10009at3193  LOC104882588
# 1      29760_0:005709      3880_0:00298d  10009at3193  LOC100267702
# 2      29760_0:001162      3880_0:00042c  10092at3193  LOC100244127
# 3      29760_0:004e38      3880_0:0050c6  10147at3193  LOC100266467
# 4      29760_0:004e38      3880_0:007458  10147at3193  LOC100266467
# ...               ...                ...          ...           ...
# 75736  29760_0:006214      3880_0:00388f   9942at3193  LOC100256637
# 75737  29760_0:000cf8      3880_0:0073aa   9942at3193  LOC100241864
# 75738  29760_0:00180e      3880_0:0073aa   9942at3193  LOC100261021
# 75739  29760_0:006063      3880_0:0073aa   9942at3193  LOC100855403
# 75740  29760_0:006214      3880_0:0073aa   9942at3193  LOC100256637
#
#       medicago Symbol
# 0         LOC11432144
# 1         LOC11432144
# 2         LOC11432413
# 3         LOC11439919
# 4         LOC25502581
# ...               ...
# 75736     LOC11426138
# 75737     LOC11422618
# 75738     LOC11422618
# 75739     LOC11422618
# 75740     LOC11422618
#
# [75741 rows x 5 columns]

# %%
arabidopsis_tomato_nm = arabidopsis_tomato_nm.drop_duplicates(subset = 'medicago Symbol')
arabidopsis_tomato_nm = arabidopsis_tomato_nm.drop_duplicates(subset = 'grape Symbol')
arabidopsis_tomato_nm
# Out:
#       grape OrthoGene medicago OrthoGene   Orthogroup  grape Symbol  \
# 0      29760_0:005643      3880_0:00298d  10009at3193  LOC104882588
# 2      29760_0:001162      3880_0:00042c  10092at3193  LOC100244127
# 3      29760_0:004e38      3880_0:0050c6  10147at3193  LOC100266467
# 5      29760_0:005012      3880_0:006fc8  10228at3193  LOC100254135
# 6      29760_0:001d16      3880_0:003883  10488at3193  LOC100241432
# ...               ...                ...          ...           ...
# 75728  29760_0:00508d      3880_0:002d26   9828at3193  LOC100251827
# 75729  29760_0:000e78      3880_0:002354   9836at3193  LOC100252520
# 75730  29760_0:00354e      3880_0:002d72   9877at3193  LOC100255795
# 75732  29760_0:002a0e      3880_0:00602c   9919at3193  LOC100241131
# 75733  29760_0:000cf8      3880_0:00388f   9942at3193  LOC100241864
#
#       medicago Symbol
# 0         LOC11432144
# 2         LOC11432413
# 3         LOC11439919
# 5         LOC25502274
# 6         LOC11445193
# ...               ...
# 75728     LOC25488891
# 75729     LOC11432476
# 75730     LOC11445289
# 75732     LOC11431644
# 75733     LOC11426138
#
# [11279 rows x 5 columns]

# %%
arabi_genes_trimmed = arabi_genes.merge(how = 'inner', left_index= True, right = arabidopsis_tomato_nm[['grape Symbol','medicago Symbol']], right_on= 'medicago Symbol')
arabi_genes_trimmed = arabi_genes_trimmed.drop_duplicates(subset = 'grape Symbol', keep = False)
arabi_genes_trimmed
# Out:
#          baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 21386   31.149518       -0.714431  0.457132 -1.562854  1.180869e-01
# 69200  633.257272        0.217117  0.258116  0.841159  4.002590e-01
# 6361   344.241423       -0.042212  0.171986 -0.245440  8.061161e-01
# 34310  806.891536        2.931826  0.300105  9.769339  1.524432e-22
# 68602   83.529436       -0.758143  0.305858 -2.478746  1.318453e-02
# ...           ...             ...       ...       ...           ...
# 39774   98.111345       -0.244367  0.341673 -0.715208  4.744808e-01
# 66233  832.658028       -1.343911  0.248972 -5.397828  6.745245e-08
# 56560  932.032538        2.305578  0.269312  8.561006  1.118864e-17
# 21007  598.932000       -1.110845  0.323532 -3.433492  5.958604e-04
# 56495  221.911915        1.332557  0.552843  2.410372  1.593628e-02
#
#                padj  grape Symbol medicago Symbol
# 21386  1.748064e-01  LOC100252631     LOC11432805
# 69200  4.880336e-01  LOC100267950     LOC11423147
# 6361   8.485883e-01  LOC100256006     LOC11434621
# 34310  3.170435e-21  LOC100261092     LOC25481846
# 68602  2.524561e-02  LOC104880588     LOC25481847
# ...             ...           ...             ...
# 39774  5.597078e-01  LOC100264541     LOC25479704
# 66233  3.291254e-07  LOC100262553     LOC25494380
# 56560  1.582861e-16  LOC100248921     LOC25494378
# 21007  1.515651e-03  LOC100240996     LOC11409691
# 56495  2.989373e-02  LOC100263041     LOC11424645
#
# [9227 rows x 8 columns]

# %%
tomato_genes_trimmed = tomato_genes.merge(how = 'inner', left_index= True, right = arabidopsis_tomato_nm[['grape Symbol','medicago Symbol']], right_on= 'grape Symbol')
tomato_genes_trimmed = tomato_genes_trimmed.drop_duplicates(subset = 'medicago Symbol', keep = False)
tomato_genes_trimmed
# Out:
#           baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 17331   463.016009       -0.146342  0.100491  -1.456274  1.453169e-01
# 14249  1194.390907       -0.278530  0.063201  -4.407017  1.048041e-05
# 46829   669.598078        1.197776  0.085197  14.058949  6.788675e-45
# 52814   432.576111        0.152691  0.101244   1.508156  1.315147e-01
# 56417   218.196777        0.040897  0.148755   0.274925  7.833741e-01
# ...            ...             ...       ...        ...           ...
# 66777   243.937664       -0.148554  0.137953  -1.076847  2.815486e-01
# 57843   221.141273       -0.083682  0.137262  -0.609650  5.420937e-01
# 73841   475.868085       -0.085229  0.093690  -0.909695  3.629833e-01
# 27427  1097.293339        0.313513  0.065313   4.800169  1.585315e-06
# 28544  1459.678318       -0.266181  0.059355  -4.484525  7.307638e-06
#
#                padj  grape Symbol medicago Symbol
# 17331  2.550804e-01  LOC100257674     LOC11427264
# 14249  6.163167e-05  LOC100254292     LOC25485777
# 46829  5.530966e-43  LOC100266436     LOC11436423
# 52814  2.361831e-01  LOC100256140     LOC25488435
# 56417  8.597540e-01  LOC100250986     LOC25489786
# ...             ...           ...             ...
# 66777  4.203753e-01  LOC100253502     LOC11446732
# 57843  6.715941e-01  LOC104877790     LOC25483066
# 73841  5.052755e-01  LOC100263890     LOC11441712
# 27427  1.066467e-05  LOC100260359     LOC25502432
# 28544  4.422078e-05  LOC100258729     LOC11445004
#
# [9058 rows x 8 columns]

# %%
tomato_genes_trimmed
# Out:
#           baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 17331   463.016009       -0.146342  0.100491  -1.456274  1.453169e-01
# 14249  1194.390907       -0.278530  0.063201  -4.407017  1.048041e-05
# 46829   669.598078        1.197776  0.085197  14.058949  6.788675e-45
# 52814   432.576111        0.152691  0.101244   1.508156  1.315147e-01
# 56417   218.196777        0.040897  0.148755   0.274925  7.833741e-01
# ...            ...             ...       ...        ...           ...
# 66777   243.937664       -0.148554  0.137953  -1.076847  2.815486e-01
# 57843   221.141273       -0.083682  0.137262  -0.609650  5.420937e-01
# 73841   475.868085       -0.085229  0.093690  -0.909695  3.629833e-01
# 27427  1097.293339        0.313513  0.065313   4.800169  1.585315e-06
# 28544  1459.678318       -0.266181  0.059355  -4.484525  7.307638e-06
#
#                padj  grape Symbol medicago Symbol
# 17331  2.550804e-01  LOC100257674     LOC11427264
# 14249  6.163167e-05  LOC100254292     LOC25485777
# 46829  5.530966e-43  LOC100266436     LOC11436423
# 52814  2.361831e-01  LOC100256140     LOC25488435
# 56417  8.597540e-01  LOC100250986     LOC25489786
# ...             ...           ...             ...
# 66777  4.203753e-01  LOC100253502     LOC11446732
# 57843  6.715941e-01  LOC104877790     LOC25483066
# 73841  5.052755e-01  LOC100263890     LOC11441712
# 27427  1.066467e-05  LOC100260359     LOC25502432
# 28544  4.422078e-05  LOC100258729     LOC11445004
#
# [9058 rows x 8 columns]

# %%
arabi_genes_trimmed = arabi_genes_trimmed.loc[arabi_genes_trimmed['medicago Symbol'].isin(tomato_genes_trimmed['medicago Symbol'])]
tomato_genes_trimmed = tomato_genes_trimmed.loc[tomato_genes_trimmed['grape Symbol'].isin(arabi_genes_trimmed['grape Symbol'])]

# %%
tomato_genes_trimmed
# Out:
#           baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 17331   463.016009       -0.146342  0.100491  -1.456274  1.453169e-01
# 14249  1194.390907       -0.278530  0.063201  -4.407017  1.048041e-05
# 46829   669.598078        1.197776  0.085197  14.058949  6.788675e-45
# 52814   432.576111        0.152691  0.101244   1.508156  1.315147e-01
# 56417   218.196777        0.040897  0.148755   0.274925  7.833741e-01
# ...            ...             ...       ...        ...           ...
# 66777   243.937664       -0.148554  0.137953  -1.076847  2.815486e-01
# 57843   221.141273       -0.083682  0.137262  -0.609650  5.420937e-01
# 73841   475.868085       -0.085229  0.093690  -0.909695  3.629833e-01
# 27427  1097.293339        0.313513  0.065313   4.800169  1.585315e-06
# 28544  1459.678318       -0.266181  0.059355  -4.484525  7.307638e-06
#
#                padj  grape Symbol medicago Symbol
# 17331  2.550804e-01  LOC100257674     LOC11427264
# 14249  6.163167e-05  LOC100254292     LOC25485777
# 46829  5.530966e-43  LOC100266436     LOC11436423
# 52814  2.361831e-01  LOC100256140     LOC25488435
# 56417  8.597540e-01  LOC100250986     LOC25489786
# ...             ...           ...             ...
# 66777  4.203753e-01  LOC100253502     LOC11446732
# 57843  6.715941e-01  LOC104877790     LOC25483066
# 73841  5.052755e-01  LOC100263890     LOC11441712
# 27427  1.066467e-05  LOC100260359     LOC25502432
# 28544  4.422078e-05  LOC100258729     LOC11445004
#
# [8185 rows x 8 columns]

# %%
tomato_genes_trimmed = (tomato_genes_trimmed.set_index('medicago Symbol')
          .reindex(arabi_genes_trimmed.set_index('medicago Symbol').index)
          .reset_index()
       )

# %%
tomato_genes_trimmed
# Out:
#      medicago Symbol     baseMean  log2FoldChange     lfcSE       stat  \
# 0        LOC11432805   152.017726        3.108675  0.211808  14.676827
# 1        LOC11423147   207.931264        0.369568  0.141277   2.615910
# 2        LOC11434621   579.574388        0.105893  0.083991   1.260771
# 3        LOC25481846   972.291950       -0.122205  0.070792  -1.726257
# 4        LOC25481847   134.231523       -0.140382  0.165648  -0.847467
# ...              ...          ...             ...       ...        ...
# 8180     LOC25480527  1327.205111        0.153030  0.064210   2.383262
# 8181     LOC25494380   376.567517       -0.354780  0.107585  -3.297663
# 8182     LOC25494378   635.897937        0.139876  0.080287   1.742185
# 8183     LOC11409691   412.572695        0.137996  0.096607   1.428423
# 8184     LOC11424645   100.858716       -0.742985  0.193195  -3.845782
#
#             pvalue          padj  grape Symbol
# 0     9.073840e-49  8.227436e-47  LOC100252631
# 1     8.898993e-03  2.572091e-02  LOC100267950
# 2     2.073913e-01  3.353134e-01  LOC100256006
# 3     8.430122e-02  1.661597e-01  LOC100261092
# 4     3.967347e-01  5.387656e-01  LOC104880588
# ...            ...           ...           ...
# 8180  1.715996e-02  4.505435e-02  LOC100262851
# 8181  9.749310e-04  3.708212e-03  LOC100262553
# 8182  8.147610e-02  1.617152e-01  LOC100248921
# 8183  1.531702e-01  2.658724e-01  LOC100240996
# 8184  1.201688e-04  5.715303e-04  LOC100263041
#
# [8185 rows x 8 columns]

# %%
arabi_genes_trimmed = arabi_genes_trimmed.reset_index()

# %%
sns.scatterplot(x =tomato_genes_trimmed['log2FoldChange'], y = arabi_genes_trimmed['log2FoldChange'])
plt.axvline(2, color="grey", linestyle="--")
plt.axhline(2, color="grey", linestyle="--")
plt.axvline(-2, color="grey", linestyle="--")
plt.axhline(-2, color="grey", linestyle="--")

# %%
merged_result_new = pd.DataFrame(data = zip(tomato_genes_trimmed['log2FoldChange'], arabi_genes_trimmed['log2FoldChange']), columns = ['Grape','Medicago'])

all_over_1_new = merged_result_new.loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)]
all_under_1_new = merged_result_new.loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]
discord_bottom_new = merged_result_new.loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]
discord_top_new = merged_result_new.loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)]
discord_ratio_new = (len(all_over_1_new)+len(all_under_1_new))/(len(discord_bottom_new)+len(discord_top_new))
discord_ratio_new
# Out:
# 1.6538461538461537

# %%
merged_result_new['Classification'] = 'Non-substantial'
merged_result_new['Classification'].loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)] = 'Substantial'
merged_result_new['Classification'].loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
merged_result_new['Classification'].loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
merged_result_new['Classification'].loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)]= 'Substantial'
# Out:
# /tmp/ipykernel_512254/3305174640.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)] = 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)] = 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']>log_fc_change_evaluation_value) & (merged_result_new['Medicago']<log_fc_change_evaluation_value_negative)]= 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)]= 'Substantial'
# /tmp/ipykernel_512254/3305174640.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_result_new['Classification'].loc[(merged_result_new['Grape']<log_fc_change_evaluation_value_negative) & (merged_result_new['Medicago']>log_fc_change_evaluation_value)]= 'Substantial'

# %%
sns.scatterplot(data = merged_result_new.loc[merged_result_new['Classification'] == "Substantial"] , x ='Grape', y = 'Medicago', s =10)
plt.axvline(0, color="k", linestyle="--")
plt.axhline(0, color="k", linestyle="--")
plt.axvline(1, color="grey", linestyle="--")
plt.axhline(1, color="grey", linestyle="--")
plt.axvline(-1, color="grey", linestyle="--")
plt.axhline(-1, color="grey", linestyle="--")
plt.title('Genewise Grape vs Medicago (Note Log2FC cutoff reduced to 1) \n 1.65 Concordant Genes per Discordant Gene')
plt.ylabel("Genewise log2-fold change in Medicago", fontsize = 12)
plt.xlabel("Genewise log2-fold change in Grape", fontsize = 12)
# Out:
# Text(0.5, 0, 'Genewise log2-fold change in Grape')

# %%
merged_result = pd.DataFrame(data = zip(tomato_genes_trimmed['log2FoldChange'], arabi_genes_trimmed['log2FoldChange']), columns = ['Tomato','Arabi'])
pos_thresh = 1.5
neg_thresh = -1.5
tomato_any_change = merged_result.loc[(merged_result['Tomato']>pos_thresh)|(merged_result['Tomato']<neg_thresh)]
tomato_concordant_change = merged_result.loc[((merged_result['Tomato']>pos_thresh) & (merged_result['Arabi']>pos_thresh)) | ((merged_result['Tomato']<neg_thresh) & (merged_result['Arabi']<neg_thresh))]
tomato_disconcordant_change = merged_result.loc[((merged_result['Tomato']>pos_thresh) & (merged_result['Arabi']<neg_thresh)) | ((merged_result['Tomato']<neg_thresh) & (merged_result['Arabi']>pos_thresh))]
percent_concordant_tomato = len(tomato_concordant_change)/len(tomato_any_change)
percent_non_discord_tomato = len(tomato_concordant_change)/(len(tomato_concordant_change+tomato_disconcordant_change))
print(percent_concordant_tomato)
print(percent_non_discord_tomato)


arabi_any_change = merged_result.loc[(merged_result['Arabi']>pos_thresh)|(merged_result['Arabi']<neg_thresh)]
arabi_concordant_change = merged_result.loc[((merged_result['Arabi']>pos_thresh) & (merged_result['Tomato']>pos_thresh)) | ((merged_result['Arabi']<neg_thresh) & (merged_result['Tomato']<neg_thresh))]
arabi_disconcordant_change = merged_result.loc[((merged_result['Arabi']>pos_thresh) & (merged_result['Tomato']<neg_thresh)) | ((merged_result['Arabi']<neg_thresh) & (merged_result['Tomato']>pos_thresh))]

percent_concordant_arabi = len(arabi_concordant_change)/len(arabi_any_change)
percent_non_discord_arabi = len(arabi_concordant_change)/(len(arabi_concordant_change+arabi_disconcordant_change))

print(percent_concordant_arabi)
print(percent_non_discord_arabi)
# Out:
# 0.3561643835616438
# 0.7027027027027027
# 0.018772563176895306
# 0.7027027027027027

# %%
stats.spearmanr(a=tomato_genes_trimmed['log2FoldChange'], b = arabi_genes_trimmed['log2FoldChange'] )

# %%
down = tomato_genes_trimmed[
    (tomato_genes_trimmed["log2FoldChange"] <= -2) & (tomato_genes_trimmed["padj"] <= 0.001)
]
up = tomato_genes_trimmed[
    (tomato_genes_trimmed["log2FoldChange"] >= 2) & (tomato_genes_trimmed["padj"] <= 0.001)
]
down_arabi = arabi_genes_trimmed[
    (arabi_genes_trimmed["log2FoldChange"] <= -2)
    & (arabi_genes_trimmed["padj"] <= 0.001)
]
up_arabi = arabi_genes_trimmed[
    (arabi_genes_trimmed["log2FoldChange"] >= 2) & (arabi_genes_trimmed["padj"] <= 0.001)
]

# %%
down_arabi_ortho = trimmed_arabi_ortho[
    (trimmed_arabi_ortho["log2FoldChange"] <= -2)
    & (trimmed_arabi_ortho["padj"] <= 0.001)
]
up_arabi_ortho = trimmed_arabi_ortho[
    (trimmed_arabi_ortho["log2FoldChange"] >= 2) & (trimmed_arabi_ortho["padj"] <= 0.001)]

down_ortho = trimmed_tomato_ortho[
    (trimmed_tomato_ortho["log2FoldChange"] <= -2) & (trimmed_tomato_ortho["padj"] <= 0.001)
]
up_ortho = trimmed_tomato_ortho[
    (trimmed_tomato_ortho["log2FoldChange"] >= 2) & (trimmed_tomato_ortho["padj"] <= 0.001)
]

# %%
len(up_arabi_ortho.merge(how = "inner", right_index = True, left_index= True, right = up_ortho))

# %%
up_ortho

# %%
up_arabi_ortho

# %%
up

# %%
up_arabi

# %%
up_arabi.merge(how = "inner", on = 'arabidopsis Symbol', right = up)
