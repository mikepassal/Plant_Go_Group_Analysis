# %%
import pandas as pd
import CococoNet_reader
import numpy as np
import soothsayer as sy 
import scipy as sp

# %% [markdown]
# We are doing the topological networks and saving the results to change the kernel because the soothsayer kernel is FUBAR and slow

# %%
arabi_cococonet = CococoNet_reader.read_cococonet('arabidopsis')
arabi_cococonet.head()
# Out:
#            AT1G01020  AT1G01030  AT1G01040  AT1G01050  AT1G01060  AT1G01070  \
# AT1G01020   1.000000   0.676041   0.885107   0.916603   0.167027   0.625596
# AT1G01030   0.676041   1.000000   0.707718   0.515532   0.420354   0.292083
# AT1G01040   0.885107   0.707718   1.000000   0.836387   0.545101   0.701558
# AT1G01050   0.916603   0.515532   0.836387   1.000000   0.562112   0.726964
# AT1G01060   0.167027   0.420354   0.545101   0.562112   1.000000   0.327202
#
#            AT1G01080  AT1G01090  AT1G01100  AT1G01110  ...  ATCG01070  \
# AT1G01020   0.801175   0.866369   0.954286   0.715750  ...   0.111731
# AT1G01030   0.687003   0.626281   0.483536   0.570675  ...   0.245167
# AT1G01040   0.656258   0.857046   0.657204   0.650843  ...   0.155183
# AT1G01050   0.837948   0.928252   0.952045   0.640223  ...   0.089440
# AT1G01060   0.242215   0.304953   0.217415   0.077569  ...   0.082518
#
#            ATCG01080  ATCG01090  ATCG01100  ATCG01110  ATCG01120  ATCG01130  \
# ...

# %%
soft_thresholded_arabi_cococonet = arabi_cococonet**6

# %%
soft_thresholded_arabi_cococonet
# Out:
#               AT1G01020     AT1G01030     AT1G01040     AT1G01050  \
# AT1G01020  1.000000e+00  9.546381e-02  4.808119e-01  5.930447e-01
# AT1G01030  9.546381e-02  1.000000e+00  1.256496e-01  1.877301e-02
# AT1G01040  4.808119e-01  1.256496e-01  1.000000e+00  3.423290e-01
# AT1G01050  5.930447e-01  1.877301e-02  3.423290e-01  1.000000e+00
# AT1G01060  2.171271e-05  5.516833e-03  2.623372e-02  3.154535e-02
# ...                 ...           ...           ...           ...
# ATCG01120  5.688895e-04  3.884341e-04  4.197882e-05  9.354835e-05
# ATCG01130  3.081014e-02  9.901540e-03  1.114756e-04  4.932502e-03
# ATCG01180  2.593644e-11  3.386969e-07  1.145639e-09  9.575546e-09
# ATCG01210  2.708480e-12  4.224132e-08  3.795387e-11  5.968252e-10
# ATCG01310  5.684205e-07  1.656920e-06  3.713718e-08  4.257840e-07
#
#               AT1G01060     AT1G01070     AT1G01080     AT1G01090  \
# AT1G01020  2.171271e-05  5.994635e-02  2.644625e-01  4.228791e-01
# ...

# %%
soft_thresholded_diag_0 = np.fill_diagonal(soft_thresholded_arabi_cococonet.values, 0)
soft_thresholded_diag_0

# %%
soft_thresholded_arabi_cococonet
# Out:
#               AT1G01020     AT1G01030     AT1G01040     AT1G01050  \
# AT1G01020  0.000000e+00  9.546381e-02  4.808119e-01  5.930447e-01
# AT1G01030  9.546381e-02  0.000000e+00  1.256496e-01  1.877301e-02
# AT1G01040  4.808119e-01  1.256496e-01  0.000000e+00  3.423290e-01
# AT1G01050  5.930447e-01  1.877301e-02  3.423290e-01  0.000000e+00
# AT1G01060  2.171271e-05  5.516833e-03  2.623372e-02  3.154535e-02
# ...                 ...           ...           ...           ...
# ATCG01120  5.688895e-04  3.884341e-04  4.197882e-05  9.354835e-05
# ATCG01130  3.081014e-02  9.901540e-03  1.114756e-04  4.932502e-03
# ATCG01180  2.593644e-11  3.386969e-07  1.145639e-09  9.575546e-09
# ATCG01210  2.708480e-12  4.224132e-08  3.795387e-11  5.968252e-10
# ATCG01310  5.684205e-07  1.656920e-06  3.713718e-08  4.257840e-07
#
#               AT1G01060     AT1G01070     AT1G01080     AT1G01090  \
# AT1G01020  2.171271e-05  5.994635e-02  2.644625e-01  4.228791e-01
# ...

# %%
diag_as_1_top_arabi = sy.networks.topological_overlap_measure(soft_thresholded_arabi_cococonet)

# %%
#diag_as_1_top_arabi.to_csv('/data/passala/Generated_Tables/Temp_junk/topological_overlap_matrix_soothsayer_diagnol_is_one.csv')

# %%
diag_as_1_top_arabi.to_csv('/data/passala/Generated_Tables/Temp_junk/topological_overlap_matrix_soothsayer_diagnol_is_zero.csv')
