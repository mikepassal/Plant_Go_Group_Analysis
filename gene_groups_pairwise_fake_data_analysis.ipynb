# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fake_egad_results = pd.read_csv('/data/passala/Generated_Tables/Comparing_all_go_groups_across_species/fake_egad_results.csv',index_col= 0)
fake_egad_results =fake_egad_results[['grape AUC','arabidopsis AUC','mustard AUC','soybean AUC','medicago AUC','tomato AUC','potato AUC','rice AUC','brome AUC','sorghum AUC','maize AUC']]
fake_egad_results
# Out:
#             grape AUC  arabidopsis AUC  mustard AUC  soybean AUC  \
# GO:0000001        NaN              NaN          NaN          NaN
# GO:0000002   0.487267              NaN          NaN     0.629309
# GO:0000003        NaN         0.511609     0.642222          NaN
# GO:0000006        NaN              NaN          NaN          NaN
# GO:0000007        NaN              NaN          NaN          NaN
# ...               ...              ...          ...          ...
# GO:0051184   0.556808              NaN          NaN          NaN
# GO:0051194   0.459416         0.486809          NaN     0.197257
# GO:0051182   0.590297              NaN          NaN          NaN
# GO:0051185   0.374572              NaN          NaN     0.342708
# GO:0018065   0.677689              NaN          NaN     0.364439
#
#             medicago AUC  tomato AUC  potato AUC  rice AUC  brome AUC  \
# GO:0000001           NaN         NaN         NaN       NaN        NaN
# ...

# %%
fake_go_terms_fc = pd.read_csv('/data/passala/Generated_Tables/Comparing_all_go_groups_across_species/fake_go_term_fc_results.csv',index_col = 0)
fake_go_terms_fc
# Out:
#                                                          Name     grape  \
# GO:0000001                          mitochondrion inheritance       NaN
# GO:0000002                   mitochondrial genome maintenance  0.646324
# GO:0000003                                       reproduction  0.669093
# GO:0000006  high-affinity zinc transmembrane transporter a...       NaN
# GO:0000007  low-affinity zinc ion transmembrane transporte...       NaN
# ...                                                       ...       ...
# GO:0061416                                                NaN  0.735205
# GO:0070011                                                NaN  0.685938
# GO:0051198                                                NaN       NaN
# GO:0051195                                                NaN       NaN
# GO:0051196                                                NaN       NaN
#
#             arabidopsis   mustard   soybean  medicago    tomato    potato  \
# ...

# %%
avg_fake_fc_and_fake_egad = pd.DataFrame(index = fake_go_terms_fc.index)
avg_fake_fc_and_fake_egad['AVG EGAD'] = fake_egad_results.mean(axis = 1)
avg_fake_fc_and_fake_egad['AVG FC'] = fake_go_terms_fc.mean(axis = 1)
avg_fake_fc_and_fake_egad
# Out:
#             AVG EGAD    AVG FC
# GO:0000001       NaN       NaN
# GO:0000002  0.525699  0.707259
# GO:0000003  0.494398  0.704346
# GO:0000006       NaN       NaN
# GO:0000007       NaN       NaN
# ...              ...       ...
# GO:0061416       NaN  0.695834
# GO:0070011  0.505891  0.698805
# GO:0051198       NaN  0.694250
# GO:0051195       NaN  0.787890
# GO:0051196       NaN  0.708623
#
# [44299 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (15,15))
sns.scatterplot(data = avg_fake_fc_and_fake_egad, x = 'AVG EGAD',y = 'AVG FC', s = 30)
plt.xlabel("Average EGAD Scores of Fake Groups",fontsize = 20)
plt.ylabel("Average FC Scores of Fake Groups",fontsize = 20)
plt.title("Fake Groups, generated with an average group size of 16, do not show increase in FC variance with increasing EGAD Score",fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# (array([0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
